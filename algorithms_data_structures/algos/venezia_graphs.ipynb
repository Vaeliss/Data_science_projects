# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
diG = nx.DiGraph()
multiG = nx.MultiGraph()

# %%
print(type(G))
G
# Out:
# <class 'networkx.classes.graph.Graph'>

# %%
print(type(diG))
diG
# Out:
# <class 'networkx.classes.digraph.DiGraph'>

# %%
print(type(multiG))
multiG
# Out:
# <class 'networkx.classes.multigraph.MultiGraph'>

# %%
G.nodes, G.edges
# Out:
# (NodeView(()), EdgeView([]))

# %%
edges = [("Santa Marta","Ple. Roma"),
         ("Santa Marta","San Basilio"),
         ("Santa Marta","Zattere"),
         ("Ple. Roma","Ferrovia"),
         ("Ple. Roma","Ferrovia"),
         ("Ple. Roma","Tronchetto Mercato"),
         ("Ple. Roma","Mestre"),
         ("Ple. Roma","Aeroporto Marcopolo"),
         ("Mestre","Aeroporto Marcopolo"),
         ("Ferrovia","Guglie"),
         ("Ferrovia","San Marcuola"),
         ("Ferrovia","Riva De Biasio"),
         ("Guglie","Riva De Biasio"),
         ("San Marcuola","Rialto"),
         ("San Marcuola","San Stae"),
         ("San Stae","Ca d'Oro"),
         ("Ca d'Oro","Rialto Mercato"),
         ("Rialto Mercato","Rialto"),
         ("Rialto","San Silvestro"),
         ("Rialto","San Tomà"),
         ("San Silvestro","Sant'Angelo"),
         ("Sant'Angelo","San Tomà"),
         ("San Tomà", "San Samuele"),
         ("San Tomà","Ca' Rezzonico"),
         ("Ca' Rezzonico","Accademia"),
         ("San Samuele","Accademia"),
         ("Accademia","Giglio"),
         ("Accademia","San Marco Giardinetti"),
         ("Giglio","Salute"),
         ("Salute","San Marco Vallaresso"),
         ("San Marco Vallaresso","San Zaccaria"),
         ("San Zaccaria","Arsenale"),
         ("San Zaccaria","San Giorgio"),
         ("San Zaccaria","San Servolo"),
         ("San Zaccaria","Lido SME"),
         ("San Zaccaria","Giardini Biennale"),
         ("San Zaccaria","Punta Sabbioni"),
         ("San Zaccaria","Spirito Santo"),
         ("San Zaccaria","Zattere"),
         ("San Zaccaria","Aeroporto Marcopolo"),
         ("Arsenale","Giardini Biennale"),
         ("Giardini Biennale","Lido SME"),
         ("Giardini Biennale","Sant'Elena"),
         ("Sant'Elena","Lido SME"),
         ("San Servolo","San Lazzaro"),
         ("San Giorgio","Zitelle"),
         ("Zitelle","Redentore"),
         ("Redentore","Palanca"),
         ("Palanca","Sacca Fisola"),
         ("Palanca","Zattere"),
         ("Spirito Santo","Zattere"),
         ("Zattere","San Basilio"),
         ("San Basilio","Sacca Fisola"),
         ("Sacca Fisola","Tronchetto"),
         ("Tronchetto","Tronchetto Mercato"),
         ("Tronchetto","Lido SME"),
         ("Guglie","Tre Archi"),
         ("Guglie","Crea"),
         ("Tre Archi","Sant'Alvise"),
         ("Crea","Sant'Alvise"),
         ("Sant'Alvise","Orto"),
         ("Orto","F.te Nove"),
         ("F.te Nove","Aeroporto Marcopolo"),
         ("F.te Nove","Murano Colonna"),
         ("F.te Nove","Murano Faro"),
         ("F.te Nove","Ospedale"),
         ("F.te Nove","Cimitero"),
         ("Ospedale","Celestia"),
         ("Celestia","Bacini - Arsenale Nord"),
         ("Bacini - Arsenale Nord","San Pietro"),
         ("San Pietro","Certosa"),
         ("Certosa","Lido SME"),
         ("San Pietro","Sant'Elena"),
         ("Lido SME","Punta Sabbioni"),
         ("Lido SME","Aeroporto Marcopolo"),
         ("Punta Sabbioni","Treporti"),
         ("Treporti","Burano"),
         ("Burano","Mazzorbo"),
         ("Burano","Torcello"),
         ("Burano","Lido SME"),
         ("Torcello","Mazzorbo"),
         ("Treporti","Sant'Erasmo"),
         ("Sant'Erasmo","Lazzaretto Nuovo"),
         ("Vignole","Lazzaretto Nuovo"),
         ("Vignole","Murano Faro"),
         ("Murano Faro","Murano Navagero"),
         ("Murano Navagero","Murano Museo"),
         ("Murano Venier","Murano Museo"),
         ("Murano Venier","Murano Serenella"),
         ("Murano Colonna","Murano Serenella"),
         ("Murano Colonna","Aeroporto Marcopolo"),
         ("Murano Colonna","Cimitero")]

# %%
G.add_edges_from(edges)

# %%
G.nodes, G.edges
# Out:
# (NodeView(('Santa Marta', 'Ple. Roma', 'San Basilio', 'Zattere', 'Ferrovia', 'Tronchetto Mercato', 'Mestre', 'Aeroporto Marcopolo', 'Guglie', 'San Marcuola', 'Riva De Biasio', 'Rialto', 'San Stae', "Ca d'Oro", 'Rialto Mercato', 'San Silvestro', 'San Tomà', "Sant'Angelo", 'San Samuele', "Ca' Rezzonico", 'Accademia', 'Giglio', 'San Marco Giardinetti', 'Salute', 'San Marco Vallaresso', 'San Zaccaria', 'Arsenale', 'San Giorgio', 'San Servolo', 'Lido SME', 'Giardini Biennale', 'Punta Sabbioni', 'Spirito Santo', "Sant'Elena", 'San Lazzaro', 'Zitelle', 'Redentore', 'Palanca', 'Sacca Fisola', 'Tronchetto', 'Tre Archi', 'Crea', "Sant'Alvise", 'Orto', 'F.te Nove', 'Murano Colonna', 'Murano Faro', 'Ospedale', 'Cimitero', 'Celestia', 'Bacini - Arsenale Nord', 'San Pietro', 'Certosa', 'Treporti', 'Burano', 'Mazzorbo', 'Torcello', "Sant'Erasmo", 'Lazzaretto Nuovo', 'Vignole', 'Murano Navagero', 'Murano Museo', 'Murano Venier', 'Murano Serenella')),
# ...

# %%
nx.draw(G)
plt.show()

# %%
plt.figure(figsize=(16,9))
nx.draw_networkx(G)

# %%
G.adj
# Out:
# AdjacencyView({'Santa Marta': {'Ple. Roma': {}, 'San Basilio': {}, 'Zattere': {}}, 'Ple. Roma': {'Santa Marta': {}, 'Ferrovia': {}, 'Tronchetto Mercato': {}, 'Mestre': {}, 'Aeroporto Marcopolo': {}}, 'San Basilio': {'Santa Marta': {}, 'Zattere': {}, 'Sacca Fisola': {}}, 'Zattere': {'Santa Marta': {}, 'San Zaccaria': {}, 'Palanca': {}, 'Spirito Santo': {}, 'San Basilio': {}}, 'Ferrovia': {'Ple. Roma': {}, 'Guglie': {}, 'San Marcuola': {}, 'Riva De Biasio': {}}, 'Tronchetto Mercato': {'Ple. Roma': {}, 'Tronchetto': {}}, 'Mestre': {'Ple. Roma': {}, 'Aeroporto Marcopolo': {}}, 'Aeroporto Marcopolo': {'Ple. Roma': {}, 'Mestre': {}, 'San Zaccaria': {}, 'F.te Nove': {}, 'Lido SME': {}, 'Murano Colonna': {}}, 'Guglie': {'Ferrovia': {}, 'Riva De Biasio': {}, 'Tre Archi': {}, 'Crea': {}}, 'San Marcuola': {'Ferrovia': {}, 'Rialto': {}, 'San Stae': {}}, 'Riva De Biasio': {'Ferrovia': {}, 'Guglie': {}}, 'Rialto': {'San Marcuola': {}, 'Rialto Mercato': {}, 'San Silvestro': {}, 'San Tomà': {}}, 'Sa
# ...

# %%
G.nodes["San Zaccaria"]["key words"] = ["Basilica San Marco","Palazzo Ducale","Museo Correr","Torre dell'Orologio","Piazza San Marco",
                                  "Campanile San Marco","Hotel Danieli"]

# %%
G.nodes["San Zaccaria"]
# Out:
# {'key words': ['Basilica San Marco',
#   'Palazzo Ducale',
#   'Museo Correr',
#   "Torre dell'Orologio",
#   'Piazza San Marco',
#   'Campanile San Marco',
#   'Hotel Danieli']}

# %%
G.edges(data=True)
# Out:
# EdgeDataView([('Santa Marta', 'Ple. Roma', {}), ('Santa Marta', 'San Basilio', {}), ('Santa Marta', 'Zattere', {}), ('Ple. Roma', 'Ferrovia', {}), ('Ple. Roma', 'Tronchetto Mercato', {}), ('Ple. Roma', 'Mestre', {}), ('Ple. Roma', 'Aeroporto Marcopolo', {}), ('San Basilio', 'Zattere', {}), ('San Basilio', 'Sacca Fisola', {}), ('Zattere', 'San Zaccaria', {}), ('Zattere', 'Palanca', {}), ('Zattere', 'Spirito Santo', {}), ('Ferrovia', 'Guglie', {}), ('Ferrovia', 'San Marcuola', {}), ('Ferrovia', 'Riva De Biasio', {}), ('Tronchetto Mercato', 'Tronchetto', {}), ('Mestre', 'Aeroporto Marcopolo', {}), ('Aeroporto Marcopolo', 'San Zaccaria', {}), ('Aeroporto Marcopolo', 'F.te Nove', {}), ('Aeroporto Marcopolo', 'Lido SME', {}), ('Aeroporto Marcopolo', 'Murano Colonna', {}), ('Guglie', 'Riva De Biasio', {}), ('Guglie', 'Tre Archi', {}), ('Guglie', 'Crea', {}), ('San Marcuola', 'Rialto', {}), ('San Marcuola', 'San Stae', {}), ('Rialto', 'Rialto Mercato', {}), ('Rialto', 'San Silvestro', {}), (
# ...

# %%
G.edges[("Santa Marta","Ple. Roma")]["weight"] = 6
G.edges[("Santa Marta","Ple. Roma")]["lines"] = ["4.2","5.2","6"]

# %%
G.nodes
# Out:
# NodeView(('Santa Marta', 'Ple. Roma', 'San Basilio', 'Zattere', 'Ferrovia', 'Tronchetto Mercato', 'Mestre', 'Aeroporto Marcopolo', 'Guglie', 'San Marcuola', 'Riva De Biasio', 'Rialto', 'San Stae', "Ca d'Oro", 'Rialto Mercato', 'San Silvestro', 'San Tomà', "Sant'Angelo", 'San Samuele', "Ca' Rezzonico", 'Accademia', 'Giglio', 'San Marco Giardinetti', 'Salute', 'San Marco Vallaresso', 'San Zaccaria', 'Arsenale', 'San Giorgio', 'San Servolo', 'Lido SME', 'Giardini Biennale', 'Punta Sabbioni', 'Spirito Santo', "Sant'Elena", 'San Lazzaro', 'Zitelle', 'Redentore', 'Palanca', 'Sacca Fisola', 'Tronchetto', 'Tre Archi', 'Crea', "Sant'Alvise", 'Orto', 'F.te Nove', 'Murano Colonna', 'Murano Faro', 'Ospedale', 'Cimitero', 'Celestia', 'Bacini - Arsenale Nord', 'San Pietro', 'Certosa', 'Treporti', 'Burano', 'Mazzorbo', 'Torcello', "Sant'Erasmo", 'Lazzaretto Nuovo', 'Vignole', 'Murano Navagero', 'Murano Museo', 'Murano Venier', 'Murano Serenella'))

# %%
[node for node in list(G.nodes) if "San" in node]
# Out:
# ['Santa Marta',
#  'San Basilio',
#  'San Marcuola',
#  'San Stae',
#  'San Silvestro',
#  'San Tomà',
#  "Sant'Angelo",
#  'San Samuele',
#  'San Marco Giardinetti',
#  'San Marco Vallaresso',
#  'San Zaccaria',
#  'San Giorgio',
#  'San Servolo',
#  'Spirito Santo',
#  "Sant'Elena",
#  'San Lazzaro',
#  "Sant'Alvise",
#  'San Pietro',
#  "Sant'Erasmo"]

# %%
from operator import itemgetter
sorted(G.degree,key=itemgetter(1),reverse=True)
# Out:
# [('San Zaccaria', 10),
#  ('Lido SME', 8),
#  ('Aeroporto Marcopolo', 6),
#  ('F.te Nove', 6),
#  ('Ple. Roma', 5),
#  ('Zattere', 5),
#  ('Ferrovia', 4),
#  ('Guglie', 4),
#  ('Rialto', 4),
#  ('San Tomà', 4),
#  ('Accademia', 4),
#  ('Giardini Biennale', 4),
#  ('Murano Colonna', 4),
#  ('Burano', 4),
#  ('Santa Marta', 3),
#  ('San Basilio', 3),
#  ('San Marcuola', 3),
#  ('Punta Sabbioni', 3),
#  ("Sant'Elena", 3),
#  ('Palanca', 3),
#  ('Sacca Fisola', 3),
#  ('Tronchetto', 3),
#  ("Sant'Alvise", 3),
#  ('Murano Faro', 3),
#  ('San Pietro', 3),
#  ('Treporti', 3),
#  ('Tronchetto Mercato', 2),
#  ('Mestre', 2),
#  ('Riva De Biasio', 2),
#  ('San Stae', 2),
#  ("Ca d'Oro", 2),
#  ('Rialto Mercato', 2),
#  ('San Silvestro', 2),
#  ("Sant'Angelo", 2),
#  ('San Samuele', 2),
#  ("Ca' Rezzonico", 2),
#  ('Giglio', 2),
#  ('Salute', 2),
#  ('San Marco Vallaresso', 2),
#  ('Arsenale', 2),
#  ('San Giorgio', 2),
#  ('San Servolo', 2),
#  ('Spirito Santo', 2),
#  ('Zitelle', 2),
# ...

# %%
G.degree("Santa Marta")
# Out:
# 3

# %%
list(G.neighbors("Santa Marta"))
# Out:
# ['Ple. Roma', 'San Basilio', 'Zattere']

# %%
[node for node in G.nodes if G.degree(node) > 5]
# Out:
# ['Aeroporto Marcopolo', 'San Zaccaria', 'Lido SME', 'F.te Nove']

# %%
nx.shortest_path(G,"Santa Marta","Lido SME")
# Out:
# ['Santa Marta', 'Ple. Roma', 'Aeroporto Marcopolo', 'Lido SME']

# %%
nx.shortest_path(G,"Mestre","Burano")
# Out:
# ['Mestre', 'Aeroporto Marcopolo', 'Lido SME', 'Burano']

# %%
sorted(list(nx.degree_centrality(G).items()),key=itemgetter(1),reverse=True)
# Out:
# [('San Zaccaria', 0.15873015873015872),
#  ('Lido SME', 0.12698412698412698),
#  ('Aeroporto Marcopolo', 0.09523809523809523),
#  ('F.te Nove', 0.09523809523809523),
#  ('Ple. Roma', 0.07936507936507936),
#  ('Zattere', 0.07936507936507936),
#  ('Ferrovia', 0.06349206349206349),
#  ('Guglie', 0.06349206349206349),
#  ('Rialto', 0.06349206349206349),
#  ('San Tomà', 0.06349206349206349),
#  ('Accademia', 0.06349206349206349),
#  ('Giardini Biennale', 0.06349206349206349),
#  ('Murano Colonna', 0.06349206349206349),
#  ('Burano', 0.06349206349206349),
#  ('Santa Marta', 0.047619047619047616),
#  ('San Basilio', 0.047619047619047616),
#  ('San Marcuola', 0.047619047619047616),
#  ('Punta Sabbioni', 0.047619047619047616),
#  ("Sant'Elena", 0.047619047619047616),
#  ('Palanca', 0.047619047619047616),
#  ('Sacca Fisola', 0.047619047619047616),
#  ('Tronchetto', 0.047619047619047616),
#  ("Sant'Alvise", 0.047619047619047616),
#  ('Murano Faro', 0.047619047619047616),
# ...

# %%
sorted(list(nx.betweenness_centrality(G).items()),key=itemgetter(1),reverse=True)
# Out:
# [('Aeroporto Marcopolo', 0.4332711579255357),
#  ('San Zaccaria', 0.36790895569697396),
#  ('Ple. Roma', 0.28840245775729645),
#  ('Ferrovia', 0.28265915685270515),
#  ('Lido SME', 0.23472801306902685),
#  ('F.te Nove', 0.23442323165825477),
#  ('San Marcuola', 0.20394265232974912),
#  ('Rialto', 0.14330090459122716),
#  ('San Marco Vallaresso', 0.12915173237753882),
#  ('Salute', 0.10839733742959548),
#  ('Murano Faro', 0.09405188598736985),
#  ('Giglio', 0.0901348352961256),
#  ('Accademia', 0.08370029015190304),
#  ('Murano Colonna', 0.0815668202764977),
#  ('Zattere', 0.0776327018262502),
#  ('Burano', 0.07552239533806351),
#  ('San Tomà', 0.06525857654889912),
#  ('Orto', 0.04983785628946918),
#  ('Punta Sabbioni', 0.049754955745739154),
#  ('Guglie', 0.048250554702167596),
#  ('Treporti', 0.04258405871309097),
#  ('Santa Marta', 0.04219150025601638),
#  ('Murano Serenella', 0.04078341013824885),
#  ('San Giorgio', 0.03822324628776243),
#  ('Ospedale', 0.037546631555848156),
# ...

# %%
nx.center(G)
# Out:
# ['Ferrovia', 'Aeroporto Marcopolo']
